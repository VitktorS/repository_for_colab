# %% [markdown]
# <a href="https://colab.research.google.com/github/VitktorS/repository_for_colab/blob/main/texts_match(vlookup).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel('перевод_описания_индексов.xlsx',sheet_name = 'заполнить англ описание')
df2 = pd.read_excel('перевод_описания_индексов.xlsx',sheet_name = 'перевод')
df1
# Out:
#         id                              short_description_rus  \
# 0    27171  Индекс отражает место страны в рейтинге лёгкос...
# 1    27235  Индекс конкурентоспособности стран или индекс ...
# 2    27237  Индекс отражает место страны в рейтинге конкур...
# 3    27617  Индекс отражает отношение значения сальдо счет...
# 4    27667  Индекс отражает изменение оборота розничной то...
# ..     ...                                                ...
# 569  60819  Индекс отражает место страны в рейтинге лёгкос...
# 570  60851  Индекс отражает место страны в рейтинге лёгкос...
# 571  62589  Индекс отражает место страны в рейтинге лёгкос...
# 572  62629  Индекс отражает тенденцию по поставкам оружия ...
# 573  62631  Индекс отражает тенденцию по поставкам оружия ...
#
#                                  short_description_eng
# 0    The index reflects a country's place in the ea...
# 1                                                  NaN
# ...

# %%
df2 = pd.read_excel('перевод_описания_индексов.xlsx',sheet_name = 'перевод')
df2
# Out:
#                                 short_description_rus  \
# 0   Индекс отражает место страны в рейтинге лёгкос...
# 1   Индекс конкурентоспособности стран или индекс ...
# 2   Индекс отражает место страны в рейтинге конкур...
# 3   Индекс отражает отношение значения сальдо счет...
# 4   Индекс отражает изменение оборота розничной то...
# 5   Индекс отражает уровень безработицы в стране н...
# 6   Индекс отражает уровень безработицы в стране н...
# 7   Индекс отражает доходы бюджета Азербайджана   ...
# 8   Индекс отражает уровень зарегистрированной без...
# 9   Отражает величину экспорта товаров в ценах ФОБ...
# 10  Отражает величину импорта товаров в ценах CIF ...
# 11  Индекс отражает изменение уровня гармонизирова...
# 12  Индекс отражает расходы центрального правитель...
# 13  Международные резервы включают вложения в инос...
# 14  Индекс отражает профицит/дефицит центрального ...
# 15  Индекс отражает доходы центрального правительс...
# ...

# %%
df1['short_description_eng'] = df1['short_description_rus'].map(lambda x: df2['short_description_eng'][df2['short_description_rus'] == x].iloc[0] if x in df2['short_description_rus'].tolist() else '')
df1.to_excel('описания+переводы.xlsx')
